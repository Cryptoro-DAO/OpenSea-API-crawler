# %% [markdown]
# # Read and combine feather files into a dataframe

# %% [markdown]
# __Motivation:__

# %% [markdown]
# ## Read feather files into pandas.DataFrame

# %%
# Helper functions

import os
import re
import pandas as pd


def get_abspath(path, pattern):
    """
    Search directory non-recursively for filename by name patterns
    
    Parameters
    ----------
    path : 
    pattern : 

    Returns
    -------
    a list of absolute path, use os.path.basename to get the filename
    """
    return [os.path.join(path, x) for x in os.listdir(path) if re.search(pattern, x)]


def print_filesize(abspath):
    df=pd.DataFrame({'filename': [os.path.basename(x) for x in abspath],
                     'size': [os.stat(x).st_size for x in abspath]}) \
        .set_index('filename')
    print(df)
    return df

data_dir = os.path.join(os.getcwd(), 'data', 'wallets successful event')

# %%
wallets_fn = get_abspath(os.path.join(data_dir, 'feather'), '\.feather$')
fsize = print_filesize(wallets_fn)
# Out:
#                                                          size
# filename
# alien-frens-evolution_success1.feather               46287690
# boredapekennelclub_success1.feather                 102316282
# boredapeyachtclub_success1.feather                   43145602
# clonex_success1.feather                              31176802
# coolcatsnft_A1.feather                              162405530
# coolcatsnft_A2.feather                              161271826
# coolcatsnft_A3.feather                               65333498
# coolcatsnft_AA1.feather                              81152522
# coolcatsnft_AA11.feather                             81240850
# coolcatsnft_AA2.feather                              80436530
# coolcatsnft_AA22.feather                             80853482
# coolcatsnft_補跑B.feather                                506650
# coolcatsnft_補跑E.feather                               1263210
# cryptoadz-by-gremplin_success1.feather               64466754
# cryptoskulls_success1.feather                        42334994
# cyberkongz-vx_success1.feather                       20655922
# doodlesofficial_success1.feather                    125894730
# hapeprime_success1.feather                           61072090
# kaiju-kingz_success1.feather                         53237586
# karafuru_success1.feather                            34163354
# lazy-lions_success1.feather                          62001762
# mekaverse_success1.feather                           49724250
# mfers_success1.feather                               74029434
# mutant-ape-yacht-club_success1.feather              101037154
# NFT20_success12錢包補跑10.feather                        98841826
# NFT20_success12錢包補跑11.feather                        37047362
# NFT20_success12錢包補跑12.feather                       183005874
# NFT20_success12錢包補跑13.feather                        41678906
# NFT20_success12錢包補跑14.feather                        13934570
# NFT20_success12錢包補跑15.feather                        15888090
# NFT20_success12錢包補跑16.feather                        35477058
# NFT20_success12錢包補跑3.feather                         67141434
# NFT20_success12錢包補跑4.feather                        160289322
# NFT20_success12錢包補跑5.feather                         79152090
# NFT20_success12錢包補跑6.feather                        155299970
# NFT20_success12錢包補跑7.feather                        147096602
# NFT20_success12錢包補跑8.feather                         81306034
# NFT20_success12錢包補跑9.feather                         40315906
# phantabear_success1.feather                          77904050
# proof-moonbirds_success1.feather                     55596786
# rektguy_rarelandnft_pieceofshit_ivedoneit_succe...   50513818
# world-of-women-nft_success1.feather                  54929618

# %%
lst = (pd.read_feather(each).assign(filename=os.path.basename(each)) for each in wallets_fn)
df = pd.concat(lst).drop("index", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16341655 entries, 0 to 332720
# Data columns (total 35 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   event_timestamp                   datetime64[ns]
#  1   event_type                        object
#  2   token_id                          object
#  3   num_sales                         float64
#  4   listing_time                      datetime64[ns]
#  5   token_owner_address               object
#  6   token_seller_address              object
#  7   from_account_address              object
#  8   deal_price                        float64
#  9   payment_token_symbol              object
#  10  payment_token_decimals            float64
#  11  payment_token_usdprice            float64
#  12  quantity                          float64
#  13  starting_price                    float64
#  14  ending_price                      float64
#  15  approved_account                  float64
#  16  asset_bundle                      object
#  17  auction_type                      object
#  18  bid_amount                        float64
#  19  transaction_hash                  object
#  20  block_hash                        object
#  21  block_number                      float64
#  22  is_private                        float64
#  23  duration                          float64
#  24  created_date                      object
#  25  collection_slug                   object
#  26  contract_address                  object
#  27  wallet_address_input              object
#  28  filename                          object
#  29  custom_event_name                 object
#  30  dev_fee_payment_event             object
#  31  dev_seller_fee_basis_points       float64
#  32  transaction_from_account_address  object
#  33  transaction_to_account_address    object
#  34  winner_account_address            object
# dtypes: datetime64[ns](2), float64(13), object(20)
# memory usage: 4.4+ GB

# %%
nft20 = pd.read_csv(os.path.join(os.getcwd(), 'NFT_20_list.csv'))
nft20_collection_slug = [os.path.basename(url) for url in nft20.collection_url]
nft20_collection_slug
# Out:
# ['boredapeyachtclub',
#  'mutant-ape-yacht-club',
#  'azuki',
#  'clonex',
#  'proof-moonbirds',
#  'doodles-official',
#  'meebits',
#  'cool-cats-nft',
#  'bored-ape-kennel-club',
#  'cryptoadz-by-gremplin',
#  'world-of-women-nft',
#  'hapeprime',
#  'mekaverse',
#  'karafuru',
#  'invisiblefriends',
#  'mfers',
#  'phantabear',
#  'cyberkongz-vx',
#  'coolpetsnft',
#  'lazy-lions',
#  'kaiju-kingz']

# %%
len(nft20_collection_slug)
# Out:
# 21

# %% [markdown]
# \* _N.b._ The NFT_20 list contains 21 manually selected collections.

# %%
df.groupby("collection_slug").size().sort_values(ascending=False).head(21)
# Out:
# collection_slug
# cryptokitties            141902
# parallelalpha            102269
# cool-cats-nft             98701
# rarible                   98597
# lazy-lions                87086
# boredapeyachtclub         75329
# world-of-women-nft        70453
# pudgypenguins             65318
# mutant-ape-yacht-club     64945
# phantabear                59595
# axie                      58247
# bored-ape-kennel-club     57815
# cryptoadz-by-gremplin     51987
# robotos-official          49584
# deadfellaz                49579
# adam-bomb-squad           48830
# creatureworld             48606
# thewickedcraniums         48601
# ape-gang-old              47822
# cyberkongz-vx             41806
# supducks                  40003
# dtype: int64

# %%
nft20_wallets = df[df.collection_slug.isin(nft20_collection_slug)]
nft20_wallets.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894186 entries, 214 to 332710
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   event_timestamp                   894186 non-null  datetime64[ns]
#  1   event_type                        894186 non-null  object
#  2   token_id                          893300 non-null  object
#  3   num_sales                         893300 non-null  float64
#  4   listing_time                      826665 non-null  datetime64[ns]
#  5   token_owner_address               893300 non-null  object
#  6   token_seller_address              894186 non-null  object
#  7   from_account_address              276 non-null     object
#  8   deal_price                        894186 non-null  float64
#  9   payment_token_symbol              894002 non-null  object
#  10  payment_token_decimals            894043 non-null  float64
#  11  payment_token_usdprice            894002 non-null  float64
#  12  quantity                          894186 non-null  float64
#  13  starting_price                    0 non-null       float64
#  14  ending_price                      0 non-null       float64
#  15  approved_account                  0 non-null       float64
#  16  asset_bundle                      886 non-null     object
#  17  auction_type                      160 non-null     object
#  18  bid_amount                        0 non-null       float64
#  19  transaction_hash                  894186 non-null  object
#  20  block_hash                        894143 non-null  object
#  21  block_number                      894143 non-null  float64
#  22  is_private                        826665 non-null  float64
#  23  duration                          0 non-null       float64
#  24  created_date                      894186 non-null  object
#  25  collection_slug                   894186 non-null  object
#  26  contract_address                  894186 non-null  object
#  27  wallet_address_input              894186 non-null  object
#  28  filename                          894186 non-null  object
#  29  custom_event_name                 0 non-null       object
#  30  dev_fee_payment_event             241140 non-null  object
#  31  dev_seller_fee_basis_points       256349 non-null  float64
#  32  transaction_from_account_address  256381 non-null  object
#  33  transaction_to_account_address    256381 non-null  object
#  34  winner_account_address            256381 non-null  object
# dtypes: datetime64[ns](2), float64(13), object(20)
# memory usage: 245.6+ MB

# %%
nft20_wallets.groupby("collection_slug").size().sort_values(ascending=False).head(21)
# Out:
# collection_slug
# cool-cats-nft            98701
# lazy-lions               87086
# boredapeyachtclub        75329
# world-of-women-nft       70453
# mutant-ape-yacht-club    64945
# phantabear               59595
# bored-ape-kennel-club    57815
# cryptoadz-by-gremplin    51987
# cyberkongz-vx            41806
# doodles-official         39065
# meebits                  35632
# mekaverse                30119
# coolpetsnft              28955
# clonex                   27678
# azuki                    26644
# hapeprime                24612
# mfers                    23897
# kaiju-kingz              19443
# karafuru                 15175
# proof-moonbirds          11034
# invisiblefriends          4215
# dtype: int64

# %%
nft20_wallets.wallet_address_input.nunique()
# Out:
# 104947

# %%
nft20_wallets.groupby("collection_slug")["wallet_address_input"].nunique().sort_values(ascending=False)
# Out:
# collection_slug
# mutant-ape-yacht-club    16876
# lazy-lions               12289
# cool-cats-nft            11223
# world-of-women-nft       10491
# doodles-official          9924
# boredapeyachtclub         9800
# phantabear                9599
# bored-ape-kennel-club     9368
# mekaverse                 9345
# cryptoadz-by-gremplin     8925
# hapeprime                 8785
# coolpetsnft               8350
# clonex                    7989
# meebits                   6936
# cyberkongz-vx             6824
# azuki                     6268
# kaiju-kingz               5882
# mfers                     5867
# karafuru                  5709
# proof-moonbirds           4887
# invisiblefriends          1816
# Name: wallet_address_input, dtype: int64

# %% [markdown]
# >> 這邊請惟翔研究如何刪除duplicated rows systematically

# %%
bad = nft20_wallets.duplicated(['event_timestamp', 'collection_slug', 'token_id', 'wallet_address_input'], keep=False)
sum(bad)
# Out:
# 612623

# %%
nft20_wallets[bad].sort_values('event_timestamp').set_index('filename')
# Out:
#                                        event_timestamp  event_type token_id  \
# filename
# coolcatsnft_AA22.feather           2021-04-30 12:38:59  successful       33
# NFT20_success12錢包補跑12.feather      2021-04-30 12:38:59  successful       33
# coolcatsnft_A2.feather             2021-04-30 12:38:59  successful       33
# NFT20_success12錢包補跑12.feather      2021-05-01 00:15:48  successful      586
# boredapeyachtclub_success1.feather 2021-05-01 00:15:48  successful      586
# ...                                                ...         ...      ...
# NFT20_success12錢包補跑10.feather      2022-06-02 01:34:58  successful     9443
# NFT20_success12錢包補跑10.feather      2022-06-05 15:37:39  successful     7167
# NFT20_success12錢包補跑8.feather       2022-06-05 15:37:39  successful     7167
# NFT20_success12錢包補跑14.feather      2022-06-07 09:08:06  successful     7694
# NFT20_success12錢包補跑16.feather      2022-06-07 09:08:06  successful     7694
#
#                                     num_sales               listing_time  \
# filename
# coolcatsnft_AA22.feather                  2.0                        NaT
# NFT20_success12錢包補跑12.feather             2.0                        NaT
# coolcatsnft_A2.feather                    2.0                        NaT
# NFT20_success12錢包補跑12.feather             5.0 2021-04-30 23:36:58.000000
# boredapeyachtclub_success1.feather        5.0 2021-04-30 23:36:58.000000
# ...                                       ...                        ...
# NFT20_success12錢包補跑10.feather             2.0 2022-06-01 22:31:32.794843
# NFT20_success12錢包補跑10.feather             5.0 2022-06-05 07:16:44.000000
# NFT20_success12錢包補跑8.feather              5.0 2022-06-05 07:16:44.000000
# NFT20_success12錢包補跑14.feather             4.0 2022-06-07 08:40:07.000000
# NFT20_success12錢包補跑16.feather             4.0 2022-06-07 08:40:07.000000
#
#                                                            token_owner_address  \
# filename
# coolcatsnft_AA22.feather            0xed2ab4948ba6a909a7751dec4f34f303eb8c7236
# NFT20_success12錢包補跑12.feather       0xed2ab4948ba6a909a7751dec4f34f303eb8c7236
# coolcatsnft_A2.feather              0xed2ab4948ba6a909a7751dec4f34f303eb8c7236
# NFT20_success12錢包補跑12.feather       0xf896527c49b44aab3cf22ae356fa3af8e331f280
# boredapeyachtclub_success1.feather  0xf896527c49b44aab3cf22ae356fa3af8e331f280
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x8f46d017455920ecbf72d04d95505208aaf03581
# NFT20_success12錢包補跑10.feather       0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑8.feather        0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑14.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
# NFT20_success12錢包補跑16.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
#
#                                                           token_seller_address  \
# filename
# coolcatsnft_AA22.feather            0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# NFT20_success12錢包補跑12.feather       0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# coolcatsnft_A2.feather              0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# NFT20_success12錢包補跑12.feather       0x88be3fa60ede9f532af10aba5690dfc254db929b
# boredapeyachtclub_success1.feather  0x88be3fa60ede9f532af10aba5690dfc254db929b
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0xe3f663418251186888935dc1c4979fa3a3da1bac
# NFT20_success12錢包補跑10.feather       0x4fa94ca44d1c403c7a864a4e6fb885cc3f6e92bb
# NFT20_success12錢包補跑8.feather        0x4fa94ca44d1c403c7a864a4e6fb885cc3f6e92bb
# NFT20_success12錢包補跑14.feather       0xf02aaa8e504daa449d4636a22c9be2b572f6b796
# NFT20_success12錢包補跑16.feather       0xf02aaa8e504daa449d4636a22c9be2b572f6b796
#
#                                    from_account_address    deal_price  \
# filename
# coolcatsnft_AA22.feather                           None  1.600000e+17
# NFT20_success12錢包補跑12.feather                      None  1.600000e+17
# coolcatsnft_A2.feather                             None  1.600000e+17
# NFT20_success12錢包補跑12.feather                      None  1.000000e+17
# boredapeyachtclub_success1.feather                 None  1.000000e+17
# ...                                                 ...           ...
# NFT20_success12錢包補跑10.feather                      None  2.160000e+19
# NFT20_success12錢包補跑10.feather                      None  4.190000e+18
# NFT20_success12錢包補跑8.feather                       None  4.190000e+18
# NFT20_success12錢包補跑14.feather                      None  2.660000e+18
# NFT20_success12錢包補跑16.feather                      None  2.660000e+18
#
#                                    payment_token_symbol  ...  \
# filename                                                 ...
# coolcatsnft_AA22.feather                           WETH  ...
# NFT20_success12錢包補跑12.feather                      WETH  ...
# coolcatsnft_A2.feather                             WETH  ...
# NFT20_success12錢包補跑12.feather                       ETH  ...
# boredapeyachtclub_success1.feather                  ETH  ...
# ...                                                 ...  ...
# NFT20_success12錢包補跑10.feather                       ETH  ...
# NFT20_success12錢包補跑10.feather                       ETH  ...
# NFT20_success12錢包補跑8.feather                        ETH  ...
# NFT20_success12錢包補跑14.feather                       ETH  ...
# NFT20_success12錢包補跑16.feather                       ETH  ...
#
#                                                   created_date  \
# filename
# coolcatsnft_AA22.feather            2021-04-30T12:39:43.636056
# NFT20_success12錢包補跑12.feather       2021-04-30T12:39:43.636056
# coolcatsnft_A2.feather              2021-04-30T12:39:43.636056
# NFT20_success12錢包補跑12.feather       2021-05-01T00:16:17.700252
# boredapeyachtclub_success1.feather  2021-05-01T00:16:17.700252
# ...                                                        ...
# NFT20_success12錢包補跑10.feather       2022-06-02T01:35:54.717142
# NFT20_success12錢包補跑10.feather       2022-06-05T15:37:46.798515
# NFT20_success12錢包補跑8.feather        2022-06-05T15:37:46.798515
# NFT20_success12錢包補跑14.feather       2022-06-07T09:08:30.638440
# NFT20_success12錢包補跑16.feather       2022-06-07T09:08:30.638440
#
#                                        collection_slug  \
# filename
# coolcatsnft_AA22.feather             boredapeyachtclub
# NFT20_success12錢包補跑12.feather        boredapeyachtclub
# coolcatsnft_A2.feather               boredapeyachtclub
# NFT20_success12錢包補跑12.feather        boredapeyachtclub
# boredapeyachtclub_success1.feather   boredapeyachtclub
# ...                                                ...
# NFT20_success12錢包補跑10.feather          proof-moonbirds
# NFT20_success12錢包補跑10.feather       world-of-women-nft
# NFT20_success12錢包補跑8.feather        world-of-women-nft
# NFT20_success12錢包補跑14.feather                    mfers
# NFT20_success12錢包補跑16.feather                    mfers
#
#                                                               contract_address  \
# filename
# coolcatsnft_AA22.feather            0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# NFT20_success12錢包補跑12.feather       0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# coolcatsnft_A2.feather              0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# NFT20_success12錢包補跑12.feather       0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# boredapeyachtclub_success1.feather  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑10.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑8.feather        0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑14.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑16.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
#
#                                                           wallet_address_input  \
# filename
# coolcatsnft_AA22.feather            0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# NFT20_success12錢包補跑12.feather       0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# coolcatsnft_A2.feather              0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# NFT20_success12錢包補跑12.feather       0x88be3fa60ede9f532af10aba5690dfc254db929b
# boredapeyachtclub_success1.feather  0x88be3fa60ede9f532af10aba5690dfc254db929b
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x8f46d017455920ecbf72d04d95505208aaf03581
# NFT20_success12錢包補跑10.feather       0x4fa94ca44d1c403c7a864a4e6fb885cc3f6e92bb
# NFT20_success12錢包補跑8.feather        0x4fa94ca44d1c403c7a864a4e6fb885cc3f6e92bb
# NFT20_success12錢包補跑14.feather       0xf02aaa8e504daa449d4636a22c9be2b572f6b796
# NFT20_success12錢包補跑16.feather       0xf02aaa8e504daa449d4636a22c9be2b572f6b796
#
#                                     custom_event_name  \
# filename
# coolcatsnft_AA22.feather                          NaN
# NFT20_success12錢包補跑12.feather                    None
# coolcatsnft_A2.feather                            NaN
# NFT20_success12錢包補跑12.feather                    None
# boredapeyachtclub_success1.feather                NaN
# ...                                               ...
# NFT20_success12錢包補跑10.feather                    None
# NFT20_success12錢包補跑10.feather                    None
# NFT20_success12錢包補跑8.feather                     None
# NFT20_success12錢包補跑14.feather                    None
# NFT20_success12錢包補跑16.feather                    None
#
#                                                                 dev_fee_payment_event  \
# filename
# coolcatsnft_AA22.feather                                                          NaN
# NFT20_success12錢包補跑12.feather       {'asset': None, 'asset_bundle': None, 'event_t...
# coolcatsnft_A2.feather                                                            NaN
# NFT20_success12錢包補跑12.feather       {'asset': None, 'asset_bundle': None, 'event_t...
# boredapeyachtclub_success1.feather                                                NaN
# ...                                                                               ...
# NFT20_success12錢包補跑10.feather       {'asset': None, 'asset_bundle': None, 'event_t...
# NFT20_success12錢包補跑10.feather                                                    None
# NFT20_success12錢包補跑8.feather                                                     None
# NFT20_success12錢包補跑14.feather                                                    None
# NFT20_success12錢包補跑16.feather                                                    None
#
#                                    dev_seller_fee_basis_points  \
# filename
# coolcatsnft_AA22.feather                                   NaN
# NFT20_success12錢包補跑12.feather                              0.0
# coolcatsnft_A2.feather                                     NaN
# NFT20_success12錢包補跑12.feather                              0.0
# boredapeyachtclub_success1.feather                         NaN
# ...                                                        ...
# NFT20_success12錢包補跑10.feather                            500.0
# NFT20_success12錢包補跑10.feather                            400.0
# NFT20_success12錢包補跑8.feather                             400.0
# NFT20_success12錢包補跑14.feather                            250.0
# NFT20_success12錢包補跑16.feather                            250.0
#
#                                               transaction_from_account_address  \
# filename
# coolcatsnft_AA22.feather                                                   NaN
# NFT20_success12錢包補跑12.feather       0x8e05bd9fa3059ec69c15bc1a6f4d94f0ac26ce00
# coolcatsnft_A2.feather                                                     NaN
# NFT20_success12錢包補跑12.feather       0x0b742783bfac8d4b6d332e5d1b63f433fcd8c0a0
# boredapeyachtclub_success1.feather                                         NaN
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x8f46d017455920ecbf72d04d95505208aaf03581
# NFT20_success12錢包補跑10.feather       0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑8.feather        0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑14.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
# NFT20_success12錢包補跑16.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
#
#                                                 transaction_to_account_address  \
# filename
# coolcatsnft_AA22.feather                                                   NaN
# NFT20_success12錢包補跑12.feather       0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# coolcatsnft_A2.feather                                                     NaN
# NFT20_success12錢包補跑12.feather       0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# boredapeyachtclub_success1.feather                                         NaN
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑10.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑8.feather        0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑14.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
# NFT20_success12錢包補跑16.feather       0x7f268357a8c2552623316e2562d90e642bb538e5
#
#                                                         winner_account_address
# filename
# coolcatsnft_AA22.feather                                                   NaN
# NFT20_success12錢包補跑12.feather       0x0b742783bfac8d4b6d332e5d1b63f433fcd8c0a0
# coolcatsnft_A2.feather                                                     NaN
# NFT20_success12錢包補跑12.feather       0x0b742783bfac8d4b6d332e5d1b63f433fcd8c0a0
# boredapeyachtclub_success1.feather                                         NaN
# ...                                                                        ...
# NFT20_success12錢包補跑10.feather       0x8f46d017455920ecbf72d04d95505208aaf03581
# NFT20_success12錢包補跑10.feather       0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑8.feather        0x0cc901998f14e88b7669e7a01863acc8f64905f7
# NFT20_success12錢包補跑14.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
# NFT20_success12錢包補跑16.feather       0xbb0baa3ca39863a2a48c7d10fde5d166a60e363d
#
# [612623 rows x 34 columns]

# %% [markdown]
# ## Event Contracts
#
# What can we do this this?

# %%
df.contract_address.unique()
# Out:
# array(['0x7f268357a8c2552623316e2562d90e642bb538e5',
#        '0x7be8076f4ea4a4ad08075c2508e481d6c946d12b',
#        '0xcd4ec7b66fbc029c116ba9ffb3e59351c20b5b06',
#        '0xb1690c08e213a35ed9bab7b318de14420fb57d8c',
#        '0x93f2a75d771628856f37f256da95e99ea28aafbe',
#        '0xf4985070ce32b6b1994329df787d1acc9a2dd9e2',
#        '0xfbeef911dc5821886e1dda71586d90ed28174b7d',
#        '0x2947f98c42597966a0ec25e92843c09ac17fbaa7',
#        '0x41a322b28d0ff354040e2cbc676f0320d8c8850d',
#        '0x131aebbfe55bca0c9eaad4ea24d386c5c082dd58',
#        '0x8e5660b4ab70168b5a6feea0e0315cb49c8cd539',
#        '0x491c05896ef656d7fee0fb90ce487315ff0ac14c',
#        '0x7e3abde9d9e80fa2d1a02c89e0eae91b233cde35',
#        '0x080bf510fcbf18b91105470639e9561022937712',
#        '0x7a6425c9b3f5521bfa5d71df710a2fb80508319b',
#        '0x23b45c658737b12f1748ce56e9b6784b5e9f3ff8',
#        '0x8c9f364bf7a56ed058fc63ef81c6cf09c833e656',
#        '0x6d7c44773c52d396f43c2d511b81aa168e9a7a42',
#        '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb', None,
#        '0xb6dae651468e9593e4581705a09c10a76ac1e0c8',
#        '0x8c530a698b6e83d562db09079bc458d4dad4e6c5',
#        '0xa5af48b105ddf2fa73cbaac61d420ea31b3c2a07',
#        '0xe479dfd9664c693b2e2992300930b00bfde08233',
#        '0x7192bb75777dab47ef6fbf6f6c0e4bcbb2294f38',
#        '0x1f52b87c3503e537853e160adbf7e330ea0be7c4',
#        '0xbd4b50bbf385195c410a625681ff29d439ba61f3',
#        '0x0ba51d9c015a7544e3560081ceb16ffe222dd64f',
#        '0x61935cbdd02287b511119ddb11aeb42f1593b7ef',
#        '0xb8402001e82ae32b99cc77c23a44ead68cbdc8b1',
#        '0x57964e649ea3735757d6898ca56f135f4437e554',
#        '0x338ffc2cafc121bc83bf7a610ccc136ba7247b64',
#        '0xf2ee97405593bc7b6275682b0331169a48fedec7',
#        '0xe7232a9fd8bf427aa41918bc008d32290e22990e',
#        '0xb2c3531f77ee0a7ec7094a0bc87ef4a269e0bcfc',
#        '0xe658e6eb4b478da2cf36d9e3712ba0c1b33786a1',
#        '0x649eff2dc5d9c5c641260c8b9bede4770fccf5e7',
#        '0x1f0678d1238921dc99309360668b16a17098aa2a',
#        '0xca891ae246e7177aad7b50dfb1b5e9993a63eafe',
#        '0x78997e9e939daffe7eb9ed114fbf7128d0cfcd39',
#        '0xb3bca6f5052c7e24726b44da7403b56a8a1b98f8',
#        '0xaeb960ed44c8a4ce848c50ef451f472a503456b2',
#        '0x6c424c25e9f1fff9642cb5b7750b0db7312c29ad',
#        '0x17a03553719001e05dc19a20f5e82ee76923a985',
#        '0xb5aa1fb7027290d6d5cbbe3b1aecd5317fa582ec',
#        '0xd01c92937400dd1ece24992b1dc44aeaa47ae72a'], dtype=object)

# %% [markdown]
# ## Write `DataFrame` to parquet format and read it (WIP)
